# %% [markdown]
# # First Week Assignment
#
# ## Test Your Knowledge: Quiz

# %% [markdown]
# **1. What are the six main reasons that people choose to use Python?**
# Ans: The main reason are:-
# i. Readable and Maintainable Code.
# ii. Multiple Programming Paradigm.
# iii. Compatible with Major Platforms and System.
# iv. Robust Standard Library.
# v. Many Open Source Frameworks and Tools.
# vi. Simplify Complex Software Development and Adopt Test Driven Development.

# %% [markdown]
# **2. Name four notable companies or organizations using Python today?**
# Ans: The notable companies / organization are:-
# i. Instagram
# ii. Spotify
# iii. Amazon
# iv. Facebook, Disque, etc...

# %% [markdown]
# **3. Why might you not want to use Python in an application?**
# Ans: Reason why not use Python in an application are:-
# i. Speed Limitation
# ii. Weeak in Mobile Computing and Browsers
# iii. Design Restriction
# iv. Underdeveloped Database Access Layers

# %% [markdown]
# **4. What can you do with Python?**
# Ans: We can do the following things with python:-
# i. Web Development
# ii. Automation and Scripting
# iii. Building Games
# iv. Web Scraping
# v. Data Science and Machine Learning

# %% [markdown]
# **5. What's the significance of the Python import this statement?**
# Ans: The significance of the Python import this statement is that import statement allows us to import one or more modules in our python program, and letting us to make use of the definitions contructed in those modules.

# %% [markdown]
# **6. Why does "spam" show up in so many Python examples in books and on the Web?**
# Ans: The python programming language is named after 'Monty Python' show, which prefer to use spam, ham and eggs as metasyntactic variables, instead of traditional foo, bar and baz. It is also popular because 'spam' is convenient and short name.

# %% [markdown]
# **7. What is your favourite color?**
# Ans: My favourite color is black and white.

# %% [markdown]
# ## Test Your Knowledge: Quiz

# %% [markdown]
# **1. What is the Python interpreter?**
# Ans: The python interpreter takes the code that we write and convert it into the language that the computer's hardware understand.
# It does this each time we run a python script.
# Python interpreter convert the source code into machine code.

# %% [markdown]
# **2. What is source code?**
# Ans: The code we write in any programming language that contain string of words, numbers, symbols that a computer programmer uses is called source code.

# %% [markdown]
# **3. What is byte code?**
# Ans: When the python script compiles, it automatically generate a compiled code knows as byte code.
# A byte code is a low-level platform-independent representation of your source code, however, it is not the binary machine code and cannot be run by the target machine directly.
# Infact, it is a set of instructions for a virtual machine which is called the Python Virtual Machine (PVM).

# %% [markdown]
# **4. What is PVM?**
# Ans: PVM stands for Python Virtual Machine.
# PVM is a software / interpreter that convert the byte code into machine code for the given operating system.
# PVM is also called the python interpreter and this is the reason why python is called interpreted language.

# %% [markdown]
# **5. Why might you need ot reload a module?**
# Ans: We need to relaod a module because if we have edited the module source file using an external editor and want to try out the new version without leaving the python interpreter, in this case reload is useful.

# %% [markdown]
# **6. How do you run a script from within IDLE?**
# Ans: we can run the script by going "Run --> Run Module" or simply hitting **F5** or (on some system, **Fn+F5**).

# %% [markdown]
# **7. Name two pitfalls related to using IDLE?**
# Ans: The two pitfalls related to using IDLE are:-
# i. IDLE can still be hung by some type of program-especially GUI programs that perform mullit-threading.
# ii. IDLE has some usability features that can burn you once you leave the IDLE GUI.

# %% [markdown]
# **8. What is a namespace, and how does it relate to module files?**
# Ans: Namespace is a system that has a unique name for each and every object in Python. An object might be a variable or a method. Name (which means name, a unique identifier) + space (which talk something related to scope).
# Modules are probably best understood as places to define names you want visible to the rest of a system. In Python-speak, modules are a namespace-a place where names are created.
# Technically, modules correspond to files, and Python create a module object to contain all the names defined in the file; but in simple terms, modules are just namespaces.

# %% [markdown]
# ## Test Your Knowledge: Quiz

# %% [markdown]
# **1. Name four of Python's core data types?**
# Ans: Python's core data types are:-
# i. Numbers
# ii. String
# iii. list, tuples
# iv. Dictionary, files and sets.

# %% [markdown]
# **2. Why they are called core datatype?**
# Ans: They are called core data types because they are effectively built into the Python language. This implies that there is a specific syntax for generating most of them.

# %% [markdown]
# **3. What does "immutable" mean, and which three of Python's core types are considered immutable?**
# Ans: Immutable object is an object that cann't be changed after it is created.
# Numbers, strings, and tuples are the immutable data types of python.

# %% [markdown]
# **4. What does "sequence" mean, and which three types fall into that category?**
# Ans: A "sequence" is a positionally ordered collections of objects.
# Strings, lists, and tuples are all sequences in python.
# They share common sequence operations, such as indexing, concatenation, and slicing, but also have type-specific methods calls.

# %% [markdown]
# **5. What does "mapping" mean, and which core type is a mapping?**
# Ans: "Mapping" denotes an object that maps key to associated values.
# Python's dictionary is the only mapping type in the core type set.

# %% [markdown]
# **6. What is "polymorphism," and why should you care?**
# Ans: Polymorphism means many forms.
# It is very important concept in programming because it refers to the use of single type entity(method, operator or object) to represent different types in different scenarios.

# %% [markdown]
# ## Projects:-

# %% [markdown]
# **1. Open a Python shell, enter the following expressions, and observe the results:**<br>
# a. 8<br>
# b. 8 * 2<br>
# c. 8 ** 2<br>
# d. 8/12<br>
# e. 8 // 12<br>
# f. 8/0

# %%
8
# Out:
# 8

# %%
8 * 2
# Out:
# 16

# %%
8 ** 2
# Out:
# 64

# %%
8 / 12
# Out:
# 0.6666666666666666

# %%
8 // 12
# Out:
# 0

# %%
# Note: This give zero division error

8 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-66a185f2637e> in <module>
#       1 # Note: This give zero division error
#       2
# ----> 3 8 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **2. Write a Python program that prints (displays) your name, address, and telephone number**

# %%
def display_details():
    name = 'Sagar Budhathoki'
    age = 22
    number = 9817890939
    
    print(f"""
    name: {name},
    age: {age},
    telephone_number: {number}
    """)
    
display_details()
# Out:
#     name: Sagar Budhathoki,
#     age: 22,
#     telephone_number: 9817890939

# %% [markdown]
# **3. Evaluate the following code at a shell prompt: print("Your name is", name). Then assign name an appropriate value, and evaluate the statement again.**

# %%
print("Your name is", name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4ad88697f405> in <module>
# ----> 1 print("Your name is", name)
#
# NameError: name 'name' is not defined

# %%
name = 'Sagar Budhatoki'
print("Your name is", name)
# Out:
# Your name is Sagar Budhatoki

# %% [markdown]
# **4. Write and test a program that accepts the user's name(as text) and age(as a number) as input. The program should output a sentence containing the user's name and age.**

# %%
name = input("Enter the name: ")
age = int(input("Enter the age: "))


output = f"Your name is {name} and age is {age}."
print(output)
# Out:
# Enter the name: Sagar Budhathoki
# Enter the age: 22
# Your name is Sagar Budhathoki and age is 22.

# %% [markdown]
# #### 5. Write and test a program that computes the area of a circle. This program should request a number representing  a radius as input from the user. It should use the formula 3.14*radius**2 to compute the area and then output this result suitably labeled.

# %%
radius = float(input("Enter the radius of the circle: "))

def calculate_area(radius):
    result = 3.14 * radius ** 2
    return f"The area of circle is {result}."

calculate_area(radius)
# Out:
# Enter the radius of the circle: 1
# 'The area of circle is 3.14.'

# %% [markdown]
# **6. Enter an input statement using the input function at the shell prompt. When the prompt asks you for input, enter a number. Then, attempt to add 1 to that number, observe the results and explain what happened.**

# %%
user_input = int(input("Enter the number: "))

def adding_one(i):
    result = i + 1
    print(f"Your result is {result}.")
    
adding_one(user_input)
# Out:
# Enter the number: 12
# Your result is 13.

# %% [markdown]
# Explanation:
# Here, we take the input from the user and convert it into the integer datatype. Then, we create a function that add one to the user input and return it. And at last, we print the result.

# %% [markdown]
# **7. Enter the expression help() at the shell prompt. Follow the instructions to browse the topics and modules.**

# %%
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> integer
# No Python documentation found for 'integer'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help> str
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
# ...

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
help([1, 2, 3])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %% [markdown]
# **8. The tax calculator program of the case study outputs a floating-point number that might show more than two digits of precision. Use the round function to modify the program to display at most two digits of precision in the output number.**

# %%
tax_rate = 5.66
standard_deduction = 100000.00
dependent_deduction = 3000.00

# input
grossIncome = float(input("Enter the gross income: "))
numDependent = int(input("Enter the number of dependents: "))

# compute income tax
taxable_income = grossIncome - standard_deduction - dependent_deduction * numDependent
income_tax = taxable_income * tax_rate

# result 
result = f"The income tax is {income_tax:.2f}"
print(result)
# Out:
# Enter the gross income: 234234324
# Enter the number of dependents: 432
# The income tax is 1317864913.84

# %% [markdown]
# **9. You can calculate the surface area of a cube if you know the length of an edge. Write a program that takes the length of an edge(an integer) as input and prints the cube's surface area as output.**

# %%
input_length = float(input("Enter the lenght of the edge: "))

surface_area = 6 * (input_length * input_length)

print(f"Surface area of the cube is {surface_area}.")
# Out:
# Enter the lenght of the edge: 23
# Surface area of the cube is 3174.0.

# %% [markdown]
# #### 10.Five Star Retro Video rents VHS tapes and DVDs to the same connoisseurs who like to buy LP record albums. The store rents new videos for 3.00 a night, and oldies for 2.00 a night.
#
# #### Write a program that the clerks at Five Star Retro Video can use to calculate the total charge for a customer’s video rentals.
#
# #### The program should prompt the user for the number of each type of video and output the total cost.

# %%
videos = int(input("Enter the number of new videos: "))
oldies = int(input("Enter the number of oldies: "))

result = (videos * 3.00) + (oldies * 2.00)
print(f"The total cost is {result}.")
# Out:
# Enter the number of new videos: 2
# Enter the number of oldies: 3
# The total cost is 12.0.

# %% [markdown]
# **11. Write a program that takes the radius of a sphere(a floating point number) as input and then outputs the sphere's diameter, circumference, surface area and volume.**

# %%
radius = float(input("Enter the radius of the circle: "))

diameter = 2 * radius
circumference = diameter * 3.14
surface_area = 4 * 3.12 * radius * radius
volume = 4 / 3 * (3.14 * radius * radius * radius)

print("Diameter: ", diameter)
print("Circumference: ", circumference)
print("Surface area: ", surface_area)
print("Volume: ", volume)
# Out:
# Enter the radius of the circle: 5
# Diameter:  10.0
# Circumference:  31.400000000000002
# Surface area:  312.0
# Volume:  523.3333333333333

# %% [markdown]
# **12. Instructions An object's momentum is its mass multiplied by its velocity. Write a program that accepts an object's mass (in kilograms) and velocity (in meters per second) as inputs, and then outputs its momentum.**

# %%
mass = input("Please input the Mass of the object :")
velocity = input("Please input the Velocity of the object:")

def momentum (m, v):
    return( float(m)*float(v))

print(f"Momentum of an object is {momentum(mass, velocity)}.")
# Out:
# Please input the Mass of the object :12
# Please input the Velocity of the object:32
# Momentum of an object is 384.0.

# %% [markdown]
# **13. The kinetic energy of a moving object is given by the formula KE = ½mv2 where m is the object’s mass and v is its velocity.**
#
# **Modify the program you created in Project 5 so that it prints the object’s kinetic energy as well as its momentum.**

# %%
mass = float(input("Mass: "))
velocity = float(input("Velocity: "))

KE = 0.5 * mass * velocity ** 2

momentum = mass * velocity

print("Momentum of an object is " + str(momentum) + ".")
print("Kinetic Energy of an object is "+str(KE) + ".")
# Out:
# Mass: 12
# Velocity: 21
# Momentum of an object is 252.0.
# Kinetic Energy of an object is 2646.0.

# %% [markdown]
# **14. An employee’s total weekly pay equals the hourly wage multiplied by the total number of regular hours plus any overtime pay. Overtime pay equals the total overtime hours multiplied by 1.5 times the hourly wage. Write a program that takes as inputs the hourly wage, total regular hours, and total overtime hours and displays an employee’s total weekly pay.**

# %%
hourly_wage = float(input("What is your hourly wage?: "))
regular_hours= float(input("How many regular hours did you work this week?: "))
overtime_hours= float(input("How many overtime hours did you have this week?: "))

overtime_wage = 1.5 * hourly_wage

weekly_pay= (hourly_wage * regular_hours) + (overtime_hours * overtime_wage)

print(f"Your total weekly pay is {weekly_pay}.")
# Out:
# What is your hourly wage?: 23423
# How many regular hours did you work this week?: 423
# How many overtime hours did you have this week?: 23423
# Your total weekly pay is 832863322.5.
